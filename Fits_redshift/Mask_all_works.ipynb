# %%
import numpy as np
import healpy as hp
import ConfigParser
from astropy.io import fits as pyfits
import matplotlib.pyplot as plt
import sys

#21cm from Flask
#decrescente
#mapas_21 = np.zeros((30,786432))
#for i in range(1,30):
#    a=30-i
#    mapas_21[a,:]= hp.read_map('delta-f1z' + str(i) + '.fits')
#    print "lendo-->", a


#crescente
mask_maps = np.zeros((30,786432))
for i in range(1,30):
    a=i-1
    mask_maps[a,:]= hp.read_map('/home/karin/Desktop/gnilc/Cubo_Flask_crescente/Redshifts_bins/Foregrounds_Redshift/fits/Mask_Foregrounds_Cubo_Redshift_' + str(i) + '.fits')
    print "lendo-->", a

pyfits.writeto('Mask_Foregrounds_Cubo_Redshift_21_total', mask_maps)
print "salvei pyfits 21"
hp.mollview(mask_maps[0,:])

print "salvei flask maps"

# Foregrounds Maps

mapas_foreground = pyfits.getdata("foreground_cube_Nside256.fits")
print (mapas_foreground[0,:])
mapas_final = mapas_foreground*mask_maps
pyfits.writeto('cube_finalmap_delta_foregrounds_mask.fits', mapas_final)
hp.mollview(mapas_final[0,:])
data = pyfits.getdata("cube_finalmap_delta_foregrounds_mask.fits")
plt.show()
# Out:
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 0
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 1
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 2
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 3
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 4
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 5
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 6
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 7
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 8
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 9
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 10
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 11
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 12
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 13
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 14
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 15
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 16
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 17
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 18
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 19
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 20
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 21
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 22
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 23
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 24
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 25
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 26
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 27
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 28
# salvei pyfits 21
# salvei flask maps
# [2281.37565958 2197.26954523 2257.832011   ... 2471.68542486 2506.07543144
#  2470.65999185]

# %%
data = pyfits.getdata("cube_finalmap_delta_foregrounds_mask.fits")
hp.mollview(mapas_final[5,:])
plt.show()
