# %%
import numpy as np
import healpy as hp
import ConfigParser
from astropy.io import fits as pyfits
import matplotlib.pyplot as plt
import sys

#21cm from Flask
mapas_21 = np.zeros((30,786432))
for i in range(1,30):
    a=30-i
    mapas_21[a,:]= hp.read_map('delta-f1z' + str(i) + '.fits')
    print "lendo-->", a
# Out:
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 29
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 28
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 27
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 26
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 25
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 24
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 23
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 22
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 21
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 20
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 19
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 18
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 17
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 16
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 15
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 14
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 13
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 12
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 11
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 10
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 9
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 8
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 7
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 6
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 5
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 4
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 3
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 2
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# lendo--> 1

# %%
pyfits.getdata('delta_flask_21_matrixmap_tognilc.fits')
print "salvei pyfits 21"
#hp.write_map('counts_flask_teste.fits', mapas_21)
hp.mollview(mapas_21[0,:], "H21 - total")
# Out:
# salvei pyfits 21

# %%
pyfits.getdata('delta_flask_21_matrixmap_tognilc.fits')
print "salvei pyfits 21"
#hp.write_map('counts_flask_teste.fits', mapas_21)
hp.mollview(mapas_21[10,:], "H21 [0.2140   0.2245]")
# Out:
# salvei pyfits 21

# %%
mapas_foreground = pyfits.getdata("foreground_cube_Nside256.fits")

mapas_final = mapas_foreground + mapas_21
pyfits.writeto('final_map_delta_foregrounds.fits', mapas_final)
#hp.write_map('mapas_final0.fits', mapas_final)
hp.mollview(mapas_final[0,:])
data = pyfits.getdata("final_map_delta_foregrounds.fits")
plt.show()
