# %%
import healpy as hp
import matplotlib.pyplot as plt
import sys
from astropy.io import fits as pyfits
import os

# %%
## reading map from foregorunds script (Lucas'one)
map = pyfits.getdata("foreground_cube_freq_redshift_256.fits")

# %%
hp.mollview(map[0, :])
plt.show()

# %%
hp.write_map("foregrounds_map0.fits", map)

# %%
m0 = hp.read_map("foregrounds_map0.fits")
hp.mollview(m0)
m0.shape
# Out:
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# (786432,)

# %%
## reading map from Flask output
map_Flask = hp.read_map("counts_flask_teste.fits")
# Out:
# NSIDE = 256
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT

# %%
hp.mollview(map_Flask)

# %%
## reading map from writopyfits
mapas_21 = pyfits.getdata("counts_flask_testepyfits.fits")

# %%
hp.mollview(mapas_21[1,:])

# %%
hp.mollview(mapas_21[2,:])

# %%
hp.mollview(mapas_21[19,:])
